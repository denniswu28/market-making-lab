# %%
import pandas as pd

# %%
pd.read_csv("/data/uni/crypto/clean/okex-swap_1000/clean_basedata/2025-09-07/BTC-USDT-SWAP.csv.gz").tail(20)
# Out:
#        Unnamed: 0          start  volume      turnover      open     close  \
# 86380       86380  1757289580000    2.62  2.910886e+05  111102.5  111102.6
# 86381       86381  1757289581000    0.00  0.000000e+00  111102.6  111102.6
# 86382       86382  1757289582000   11.97  1.329897e+06  111102.5  111102.5
# 86383       86383  1757289583000    0.01  1.111025e+03  111102.5  111102.5
# 86384       86384  1757289584000    4.89  5.432913e+05  111102.5  111102.5
# 86385       86385  1757289585000  181.50  2.016510e+07  111102.5  111102.5
# 86386       86386  1757289586000  408.66  4.540119e+07  111102.5  111085.5
# 86387       86387  1757289587000  153.19  1.701704e+07  111085.5  111081.4
# 86388       86388  1757289588000    1.22  1.355192e+05  111081.3  111081.3
# 86389       86389  1757289589000    0.00  0.000000e+00  111081.3  111081.3
# 86390       86390  1757289590000    1.21  1.344084e+05  111081.3  111081.3
# ...

# %%
import polars as pl
pl.read_parquet("/data/uni/crypto/parquet_tardis/binance-futures/trades/2025-02-01/SOLUSDT.parquet")
# Out:
# shape: (1_501_305, 6)
# ┌──────────────────┬──────────────────┬────────────┬──────┬────────┬────────┐
# │ timestamp        ┆ local_timestamp  ┆ id         ┆ side ┆ price  ┆ amount │
# │ ---              ┆ ---              ┆ ---        ┆ ---  ┆ ---    ┆ ---    │
# │ i64              ┆ i64              ┆ i64        ┆ i64  ┆ f64    ┆ i64    │
# ╞══════════════════╪══════════════════╪════════════╪══════╪════════╪════════╡
# │ 1738368005365000 ┆ 1738368005367769 ┆ 2063801953 ┆ 1    ┆ 231.6  ┆ 2      │
# │ 1738368005378000 ┆ 1738368005381767 ┆ 2063801954 ┆ 1    ┆ 231.6  ┆ 1      │
# │ 1738368005404000 ┆ 1738368005407423 ┆ 2063801955 ┆ 1    ┆ 231.6  ┆ 1      │
# │ 1738368005480000 ┆ 1738368005483762 ┆ 2063801956 ┆ 2    ┆ 231.59 ┆ 1      │
# │ 1738368005480000 ┆ 1738368005483772 ┆ 2063801957 ┆ 2    ┆ 231.59 ┆ 10     │
# │ …                ┆ …                ┆ …          ┆ …    ┆ …      ┆ …      │
# │ 1738454399912000 ┆ 1738454399915013 ┆ 2065303631 ┆ 2    ┆ 212.88 ┆ 1      │
# ...

# %%
pd.read_csv("/home/wtr2/statmm/out/SOLUSDT0.csv").head(20)
# Out:
#               timestamp  balance  position  fee  trading_volume  \
# 0   1738368001052000000        0         0    0               0
# 1   1738368002052000000        0         0    0               0
# 2   1738368003052000000        0         0    0               0
# 3   1738368004052000000        0         0    0               0
# 4   1738368005052000000        0         0    0               0
# 5   1738368006052000000        0         0    0               0
# 6   1738368007052000000        0         0    0               0
# 7   1738368008052000000        0         0    0               0
# 8   1738368009052000000        0         0    0               0
# 9   1738368010052000000        0         0    0               0
# 10  1738368011052000000        0         0    0               0
# 11  1738368012052000000        0         0    0               0
# 12  1738368013052000000        0         0    0               0
# 13  1738368014052000000        0         0    0               0
# ...

# %%
import numpy as np
data = np.load("/data/tmp/tardis_bn_hft/data/binance-futures/SOLUSDT/SOLUSDT_20250131_EOD.npz")
df = data['data']
print(df.shape)
# Out:
# (12645,)

# %%
df = data['data'][-400:]
print(df)
# Out:
# [(3489660932, 0, 0,  325.65, 7.0000e+00, 0, 0, 0.)
#  (3489660932, 0, 0,  325.84, 1.0000e+00, 0, 0, 0.)
#  (3489660932, 0, 0,  325.85, 2.0000e+00, 0, 0, 0.)
#  (3489660932, 0, 0,  325.91, 2.7000e+01, 0, 0, 0.)
#  (3489660932, 0, 0,  325.92, 4.0000e+00, 0, 0, 0.)
#  (3489660932, 0, 0,  326.13, 2.0000e+00, 0, 0, 0.)
#  (3489660932, 0, 0,  326.15, 1.0000e+00, 0, 0, 0.)
#  (3489660932, 0, 0,  326.23, 1.0000e+00, 0, 0, 0.)
#  (3489660932, 0, 0,  326.37, 1.0000e+00, 0, 0, 0.)
#  (3489660932, 0, 0,  326.4 , 3.0000e+00, 0, 0, 0.)
#  (3489660932, 0, 0,  326.44, 2.0000e+00, 0, 0, 0.)
#  (3489660932, 0, 0,  326.57, 2.0000e+00, 0, 0, 0.)
#  (3489660932, 0, 0,  326.68, 2.0000e+00, 0, 0, 0.)
#  (3489660932, 0, 0,  326.69, 3.0000e+00, 0, 0, 0.)
#  (3489660932, 0, 0,  326.74, 2.6000e+01, 0, 0, 0.)
#  (3489660932, 0, 0,  326.85, 7.0000e+00, 0, 0, 0.)
#  (3489660932, 0, 0,  326.86, 1.0000e+00, 0, 0, 0.)
#  (3489660932, 0, 0,  326.91, 1.0000e+00, 0, 0, 0.)
# ...

# %%
import numpy as np
data = np.load("/data/tmp/tardis_bn_hft/data/binance-futures/SOLUSDT/SOLUSDT_20250130.npz")
df = data['data'][-200:]
print(df)
# Out:
# [(3489660929, 1738281599685000000, 1738281599688592000, 238.19, 2.1400e+02, 0, 0, 0.)
#  (3489660929, 1738281599685000000, 1738281599688592000, 238.29, 3.6800e+02, 0, 0, 0.)
#  (3489660929, 1738281599685000000, 1738281599688592000, 238.96, 1.9100e+02, 0, 0, 0.)
#  (3489660929, 1738281599685000000, 1738281599688592000, 238.98, 9.9000e+01, 0, 0, 0.)
#  (3489660929, 1738281599685000000, 1738281599688592000, 239.  , 6.9000e+01, 0, 0, 0.)
#  (3489660929, 1738281599685000000, 1738281599688592000, 240.51, 4.7000e+01, 0, 0, 0.)
#  (3758096385, 1738281599685000000, 1738281599688592000, 236.22, 3.0000e+00, 0, 0, 0.)
#  (3758096385, 1738281599685000000, 1738281599688592000, 236.46, 1.5500e+02, 0, 0, 0.)
#  (3758096385, 1738281599685000000, 1738281599688592000, 236.7 , 2.7400e+02, 0, 0, 0.)
#  (3758096385, 1738281599685000000, 1738281599688592000, 236.77, 2.4600e+02, 0, 0, 0.)
#  (3758096385, 1738281599685000000, 1738281599688592000, 237.06, 4.2100e+02, 0, 0, 0.)
# ...

# %%
data['data'].dtype
# Out:
# dtype([('ev', '<u8'), ('exch_ts', '<i8'), ('local_ts', '<i8'), ('px', '<f8'), ('qty', '<f8'), ('order_id', '<u8'), ('ival', '<i8'), ('fval', '<f8')])

# %%
import pandas as pd
pd.read_csv("/home/wtr2/statmm/out/SOLUSDT0.csv").tail(20)
