# %%
import pandas as pd

# %%
pd.read_csv("/data/uni/crypto/clean/okex-swap_1000/clean_orderbook_bps/2025-09-07/BTC-USDT-SWAP.csv.gz").tail(20)
# Out:
#        Unnamed: 0          start  volume      turnover      open     close  \
# 86380       86380  1757289580000    2.62  2.910886e+05  111102.5  111102.6
# 86381       86381  1757289581000    0.00  0.000000e+00  111102.6  111102.6
# 86382       86382  1757289582000   11.97  1.329897e+06  111102.5  111102.5
# 86383       86383  1757289583000    0.01  1.111025e+03  111102.5  111102.5
# 86384       86384  1757289584000    4.89  5.432913e+05  111102.5  111102.5
# 86385       86385  1757289585000  181.50  2.016510e+07  111102.5  111102.5
# 86386       86386  1757289586000  408.66  4.540119e+07  111102.5  111085.5
# 86387       86387  1757289587000  153.19  1.701704e+07  111085.5  111081.4
# 86388       86388  1757289588000    1.22  1.355192e+05  111081.3  111081.3
# 86389       86389  1757289589000    0.00  0.000000e+00  111081.3  111081.3
# 86390       86390  1757289590000    1.21  1.344084e+05  111081.3  111081.3
# ...

# %%
import polars as pl
pl.read_parquet("/data/uni/crypto/parquet_tardis/binance-futures/incremental_book_L2/2025-09-10/CRVUSDT.parquet")
# Out:
# shape: (4_206_736, 6)
# ┌──────────────────┬──────────────────┬─────────────┬──────┬───────┬──────────┐
# │ timestamp        ┆ local_timestamp  ┆ is_snapshot ┆ side ┆ price ┆ amount   │
# │ ---              ┆ ---              ┆ ---         ┆ ---  ┆ ---   ┆ ---      │
# │ i64              ┆ i64              ┆ i8          ┆ i64  ┆ f64   ┆ f64      │
# ╞══════════════════╪══════════════════╪═════════════╪══════╪═══════╪══════════╡
# │ 1757462400485000 ┆ 1757462401053487 ┆ 1           ┆ 2    ┆ 0.778 ┆ 110333.1 │
# │ 1757462400485000 ┆ 1757462401053487 ┆ 1           ┆ 2    ┆ 0.779 ┆ 216098.8 │
# │ 1757462400485000 ┆ 1757462401053487 ┆ 1           ┆ 2    ┆ 0.78  ┆ 206361.4 │
# │ 1757462400485000 ┆ 1757462401053487 ┆ 1           ┆ 2    ┆ 0.781 ┆ 171882.6 │
# │ 1757462400485000 ┆ 1757462401053487 ┆ 1           ┆ 2    ┆ 0.782 ┆ 163776.2 │
# │ …                ┆ …                ┆ …           ┆ …    ┆ …     ┆ …        │
# ...
