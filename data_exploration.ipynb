# %% [markdown]
# # Synthetic fixture inspection
#
# This notebook is a lightweight companion to the supported offline fixture at `fixtures/synthetic_l2.csv`. It contains no executed outputs and is safe to open from a fresh clone.

# %%
from pathlib import Path
import csv

fixture_path = Path("fixtures/synthetic_l2.csv")
with fixture_path.open() as handle:
    rows = list(csv.DictReader(handle))

rows[:3]
